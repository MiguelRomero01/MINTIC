# %% [markdown]
# Base de datos general

# %%
import pandas as pd

df_Familias_En_Accion = pd.read_csv("C:/Users/migue/Music/MINTIC/mintic/modulo1/fuente de datos/Beneficiarios_M_s_Familias_en_Acci_n_20240914.csv")	
df_Familias_En_Accion
# Out:
#         Bancarizado  CodigoDepartamentoAtencion  CodigoMunicipioAtencion  \
# 0                SI                           8                     8421
# 1                NO                          13                    13673
# 2                SI                           8                     8421
# 3                SI                           8                     8421
# 4                SI                           8                     8421
# ...             ...                         ...                      ...
# 3958589          NO                          47                    47675
# 3958590          NO                          13                    13442
# 3958591          NO                          25                    25875
# 3958592          NO                          19                    19807
# 3958593          NO                          88                    88001
#
#         Discapacidad EstadoBeneficiario                   Etnia  \
# ...

# %% [markdown]
# Eliminacion de columnas innecesarias o con datos muy poco utiles y repetitivos
#
# Columnas eliminadas: CodigoDepartamentoAtencion, Etnia, Genero, RangoUltimoBeneficioAsignado, CantidadDeBeneficiarios

# %%
Columnas_Eliminar=[
                    "CodigoDepartamentoAtencion",
                    "Etnia",
                    "Genero",
                    "RangoUltimoBeneficioAsignado",
                    "CantidadDeBeneficiarios"
                ]

try:
    df_Familias_En_Accion = df_Familias_En_Accion.drop(columns=Columnas_Eliminar)
    print("Las columnas seleccionadas se eliminaron con éxito")
except KeyError as e:
    print("Error al aliminar columnas: ",e)
# Out:
# Las columnas seleccionadas se eliminaron con éxito

# %%
df_Familias_En_Accion
# Out:
#         Bancarizado  CodigoMunicipioAtencion Discapacidad EstadoBeneficiario  \
# 0                SI                     8421           NO             ACTIVO
# 1                NO                    13673           NO          NO ACTIVO
# 2                SI                     8421           NO             ACTIVO
# 3                SI                     8421           NO             ACTIVO
# 4                SI                     8421           NO             ACTIVO
# ...             ...                      ...          ...                ...
# 3958589          NO                    47675           NO             ACTIVO
# 3958590          NO                    13442           NO             ACTIVO
# 3958591          NO                    25875           NO             ACTIVO
# 3958592          NO                    19807           NO             ACTIVO
# 3958593          NO                    88001           NO             ACTIVO
#
# ...
